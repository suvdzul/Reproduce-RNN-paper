# %%
# Access data using Google BigQuery.
from google.colab import auth
from google.cloud import bigquery

# You only need to authenticate once per session.
auth.authenticate_user()

# %%
# Import libraries
from datetime import timedelta
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_gbq

# below imports are used for pretty pandas dataframes and plots
from IPython.display import display, HTML
# %matplotlib inline
plt.style.use('ggplot')

# Set up environment variables
project_id = 'genuine-box-350018'
os.environ["GOOGLE_CLOUD_PROJECT"] = project_id
pandas_gbq.context.project = project_id

# Read data from BigQuery into pandas dataframes.
def run_query(query, project_id=project_id):
    return pd.io.gbq.read_gbq(
        query,
        project_id=project_id,
        dialect="standard"
    )

if project_id == 'CHANGE-ME':
  raise ValueError('You must change project_id to your GCP project at the top of this cell.')

  # test it works
df = run_query("""
SELECT *
FROM `physionet-data.mimic_core.patients`
WHERE subject_id = 10012853
""")
assert df.shape[0] >= 1, 'unable to query MIMIC!'
display(df)
# Out:
#    subject_id gender  anchor_age  anchor_year anchor_year_group dod
# 0    10012853      F          91         2175       2014 - 2016 NaT

# %% [markdown]
# **LABEVENTS**
#
# Known itemids for variables from labevents table as per https://github.com/USC-Melady/Benchmarking_DL_MIMICIII/blob/master/Codes/mimic3_mvcv/config/99plusf.csv.

# %%
lab_known_itemids = [51221, 51265, 51222, 51249, 51248, 51250, 51279, 51277, 50902, 50868, 50912, 50931, 
                     50960, 50893, 50970, 51237, 51274, 51275, 51244, 51254, 51256, 51146, 51200, 50820, 
                     50802, 50804, 50818, 51491, 51498, 50813, 50861, 50878, 50863, 50862]

# %% [markdown]
# Finding itemids for variables listed in the PLAN, taken from Supplementary Info, (https://github.com/suvdzul/Reproduce-RNN-paper/blob/main/PLAN.md), that don't have their itemids from labevents table in mimic_hosp.

# %%
lab_unknown = run_query(f'''
SELECT itemid, label
FROM `physionet-data.mimic_hosp.d_labitems` 
WHERE LOWER(label) LIKE '%white blood cells%'
OR LOWER(label) LIKE '%potassium%' 
OR LOWER(label) LIKE '%sodium%' 
OR LOWER(label) LIKE '%bicarbonate%' 
OR LOWER(label) LIKE '%urea nitrogen%' 
OR LOWER(label) LIKE '%bilirubin%' 
OR LOWER(label) LIKE '%po2%'
''')
pd.set_option('display.max_rows', None)
display(lab_unknown)
# Out:
#     itemid                                label
# 0    50803  Calculated Bicarbonate, Whole Blood
# 1    50821                                  pO2
# 2    50822               Potassium, Whole Blood
# 3    52452               Potassium, Whole Blood
# 4    50824                  Sodium, Whole Blood
# 5    52455                  Sodium, Whole Blood
# 6    52039               Calculated Bicarbonate
# 7    52042                                  pO2
# 8    52046                     Potassium, Urine
# 9    52047                        Sodium, Urine
# 10   50832                      pO2, Body Fluid
# 11   50833                            Potassium
# 12   50834                   Sodium, Body Fluid
# 13   50882                          Bicarbonate
# 14   50883                    Bilirubin, Direct
# 15   50884                  Bilirubin, Indirect
# 16   51568                  Bilirubin, Neonatal
# 17   51569          Bilirubin, Neonatal, Direct
# 18   51570        Bilirubin, Neonatal, Indirect
# 19   50885                     Bilirubin, Total
# 20   50971                            Potassium
# 21   52610                            Potassium
# 22   50983                               Sodium
# 23   52623                               Sodium
# 24   51006                        Urea Nitrogen
# 25   52647                        Urea Nitrogen
# 26   51755                    White Blood Cells
# 27   51756                    White Blood Cells
# 28   51061                   Bicarbonate, Stool
# 29   51932              Bilirubin, Total, Stool
# 30   51064                     Potassium, Stool
# 31   51065                        Sodium, Stool
# 32   51951                 Urea Nitrogen, Stool
# 33   51076                   Bicarbonate, Urine
# 34   51966                            Bilirubin
# 35   51097                     Potassium, Urine
# 36   51100                        Sodium, Urine
# 37   51104                 Urea Nitrogen, Urine
# 38   50837                 Bicarbonate, Ascites
# 39   50838            Bilirubin, Total, Ascites
# 40   50847                   Potassium, Ascites
# 41   50848                      Sodium, Ascites
# 42   50851               Urea Nitrogen, Ascites
# 43   51048                 Bicarbonate, Pleural
# 44   51049            Bilirubin, Total, Pleural
# 45   51057                   Potassium, Pleural
# 46   51058                      Sodium, Pleural
# 47   51922               Urea Nitrogen, Pleural
# 48   51811              Bicarbonate,Joint Fluid
# 49   51812        Bilirubin, Total, Joint Fluid
# 50   51822               Potassium, Joint Fluid
# 51   51823                  Sodium, Joint Fluid
# 52   51825           Urea Nitrogen, Joint Fluid
# 53   51027             Bicarbonate, Other Fluid
# 54   51028         Bilirubin, Total, Body Fluid
# 55   51041                Potassium, Body Fluid
# 56   51042                   Sodium, Body Fluid
# 57   51045            Urea Nitrogen, Body Fluid
# 58   51782                     Bicarbonate, CSF
# 59   51783                Bilirubin, Total, CSF
# 60   51800                       Potassium, CSF
# 61   51801                          Sodium, CSF
# 62   51804                   Urea Nitrogen, CSF
# 63   51301                    White Blood Cells
# 64   51464                            Bilirubin
# 65   51465                   Bilirubin Crystals

# %%
# choosing relevant unknown item ids
lab_unknown_chosen = [52042, 50821, 50885, 51006, 52647, 50882, 50983, 52623, 50833, 50971, 52610, 51755, 51756, 51301]
lab_str_unknown = ','.join([str(s) for s in lab_unknown_chosen])

unknown_lab_chosen = run_query(f'''
SELECT itemid, label
FROM `physionet-data.mimic_hosp.d_labitems`
WHERE itemid IN ({lab_str_unknown})
''')
display(unknown_lab_chosen)
# Out:
#     itemid              label
# 0    50821                pO2
# 1    52042                pO2
# 2    50833          Potassium
# 3    50882        Bicarbonate
# 4    50885   Bilirubin, Total
# 5    50971          Potassium
# 6    52610          Potassium
# 7    50983             Sodium
# 8    52623             Sodium
# 9    51006      Urea Nitrogen
# 10   52647      Urea Nitrogen
# 11   51755  White Blood Cells
# 12   51756  White Blood Cells
# 13   51301  White Blood Cells

# %%
# combining known and unknown together
lab_itemids = lab_known_itemids + lab_unknown_chosen
lab_itemids = ','.join([str(s) for s in lab_itemids])

# %% [markdown]
# Compiling data from labevents while applying exclusions/inclusions:
# - Exclude N/A charttime or value/valuenum
# - Only include data for first 48h after admission

# %%
lab_data = run_query(f'''
SELECT fco.subject_id, fco.hadm_id, fco.stay_id, fco.intime
, lab.itemid, it.label, lab.charttime, lab.value, lab.valuenum, lab.valueuom
, CASE WHEN DATE_DIFF(lab.charttime,  CAST(fco.intime AS date), hour) > 48 THEN 1 ELSE 0 END AS exclude_after48h
, CASE WHEN lab.charttime IS NULL THEN 1 ELSE 0 END AS exclude_null_time
, CASE WHEN (lab.value IS NULL AND lab.valuenum IS NULL) THEN 1 ELSE 0 END AS exclude_null_value
, CASE WHEN (lab.value='0' AND lab.valuenum=0) THEN 1 ELSE 0 END AS exclude_zero_none_value
, CASE WHEN lab.valueuom is NULL THEN 1 ELSE 0 END AS exclude_null_valueuom
FROM `physionet-data.mimic_hosp.labevents` lab
INNER JOIN `genuine-box-350018.rnn_dataset.final-cohort-table` fco
ON fco.hadm_id = lab.hadm_id
LEFT JOIN `physionet-data.mimic_hosp.d_labitems` it
ON it.itemid = lab.itemid
WHERE lab.itemid IN ({lab_itemids}) 
''')
display(lab_data.head())
# Out:
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
# /usr/local/lib/python3.7/dist-packages/google/cloud/bigquery/table.py:1582: FutureWarning: Data is timezone-aware. Converting timezone-aware data to timezone-naive by passing dtype='datetime64[ns]' to DataFrame or Series is deprecated and will raise in a future version. Use `pd.Series(values).dt.tz_localize(None)` instead.
#   bqstorage_client=bqstorage_client, dtypes=dtypes
#    subject_id   hadm_id   stay_id                    intime  itemid    label  \
# 0    11067215  23574374  33085406 2168-04-29 15:14:33+00:00   51237  INR(PT)
# 1    11226194  24922551  36319779 2175-12-27 02:13:39+00:00   51237  INR(PT)
# 2    11539251  21399974  38365376 2179-04-22 14:13:14+00:00   51237  INR(PT)
# 3    11955806  29300748  34127493 2170-12-23 17:17:01+00:00   51237  INR(PT)
# 4    13241710  22990223  37121997 2153-08-14 19:25:41+00:00   51237  INR(PT)
#
#             charttime value  valuenum valueuom  exclude_after48h  \
# 0 2168-04-22 05:45:00   1.9       1.9     None                 0
# 1 2175-12-29 05:17:00   1.1       1.1     None                 1
# 2 2179-04-24 02:46:00   1.3       1.3     None                 1
# 3 2170-12-23 14:07:00   1.1       1.1     None                 0
# 4 2153-08-14 18:11:00   1.1       1.1     None                 0
#
#    exclude_null_time  exclude_null_value  exclude_zero_none_value  \
# 0                  0                   0                        0
# 1                  0                   0                        0
# 2                  0                   0                        0
# 3                  0                   0                        0
# 4                  0                   0                        0
#
#    exclude_null_valueuom
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1

# %%
pandas_gbq.to_gbq(lab_data,'rnn_dataset.lab-table', project_id = project_id, if_exists = 'replace')
# Out:
# 1it [05:01, 301.22s/it]

# %%
# Let's see how it looks like for one subject 14848066
lab_data[lab_data['subject_id']==14848066]
# Out:
#          subject_id   hadm_id   stay_id                    intime  itemid  \
# 5195       14848066  20683707  35293872 2120-08-07 22:45:54+00:00   51237
# 5706       14848066  20683707  35293872 2120-08-07 22:45:54+00:00   51498
# 6901       14848066  20683707  35293872 2120-08-07 22:45:54+00:00   51200
# 6956       14848066  20683707  35293872 2120-08-07 22:45:54+00:00   51146
# 9520       14848066  20683707  35293872 2120-08-07 22:45:54+00:00   51254
# ...             ...       ...       ...                       ...     ...
# 6309611    14848066  20683707  35293872 2120-08-07 22:45:54+00:00   50821
# 6314298    14848066  20683707  35293872 2120-08-07 22:45:54+00:00   50821
# 6316442    14848066  20683707  35293872 2120-08-07 22:45:54+00:00   50818
# 6321759    14848066  20683707  35293872 2120-08-07 22:45:54+00:00   50820
# 6327739    14848066  20683707  35293872 2120-08-07 22:45:54+00:00   50813
#
#                     label           charttime  value  valuenum valueuom  \
# 5195              INR(PT) 2120-08-24 04:07:00   None       NaN     None
# 5706     Specific Gravity 2120-08-28 14:37:00  1.010      1.01
# 6901          Eosinophils 2120-08-22 14:37:00      0      0.00        %
# 6956            Basophils 2120-08-15 00:57:00      0      0.00        %
# 9520            Monocytes 2120-08-25 03:54:00      0      0.00        %
# ...                   ...                 ...    ...       ...      ...
# 6309611               pO2 2120-08-10 04:55:00     75     75.00    mm Hg
# 6314298               pO2 2120-08-08 00:14:00     45     45.00    mm Hg
# 6316442              pCO2 2120-08-14 02:42:00     39     39.00    mm Hg
# 6321759                pH 2120-08-24 09:46:00   7.41      7.41    units
# 6327739           Lactate 2120-08-09 19:49:00    2.5      2.50   mmol/L
#
#          exclude_after48h  exclude_null_time  exclude_null_value  \
# 5195                    1                  0                   1
# 5706                    1                  0                   0
# 6901                    1                  0                   0
# 6956                    1                  0                   0
# 9520                    1                  0                   0
# ...                   ...                ...                 ...
# 6309611                 1                  0                   0
# 6314298                 0                  0                   0
# 6316442                 1                  0                   0
# 6321759                 1                  0                   0
# 6327739                 1                  0                   0
#
#          exclude_zero_none_value  exclude_null_valueuom
# 5195                           0                      1
# 5706                           0                      0
# 6901                           1                      0
# 6956                           1                      0
# 9520                           1                      0
# ...                          ...                    ...
# 6309611                        0                      0
# 6314298                        0                      0
# 6316442                        0                      0
# 6321759                        0                      0
# 6327739                        0                      0
#
# [2327 rows x 15 columns]

# %% [markdown]
# Check how many records are excluded

# %%
print(lab_data['exclude_after48h'].sum())
# Out:
# 4152560

# %%
print(lab_data['exclude_null_time'].sum())
# Out:
# 0

# %%
print(lab_data['exclude_null_value'].sum())
# Out:
# 8374

# %%
print(lab_data['exclude_null_valueuom'].sum())
# Out:
# 136832

# %%
print(lab_data['exclude_zero_none_value'].sum())
# Out:
# 54752

# %%
# subsetting the dataset and removing excluded records 
lab_data=lab_data[(lab_data.exclude_after48h==0)&(lab_data.exclude_null_time==0)&(lab_data.exclude_null_value==0)&(lab_data.exclude_null_valueuom==0)&(lab_data.exclude_zero_none_value==0)][['subject_id','hadm_id', 'stay_id', 'intime', 'itemid', 'label', 'charttime', 'value','valuenum', 'valueuom']]

# %% [markdown]
# According to PLAN, 5 covariates from labevents have multiple itemids:
# * White Blood Cells = [51755, 51756, 51301]
# * Potassium = [50833, 50971, 52610]
# * Sodium = [50983, 52623]
# * Urea Nitrogen = [51006, 52647]
# * PO2 = [52042, 50821]

# %%
# For variables with duplicate codes - count occurence to see which label/measurement to use
lab_dup_itemids = [51755, 51756, 51301, 50833, 50971, 52610, 50983, 52623, 51006, 52647, 52042, 50821]
for x in lab_dup_itemids:
  print(x)
  print(len(lab_data[lab_data['itemid'] == x]))
# Out:
# 51755
# 0
# 51756
# 0
# 51301
# 70856
# 50833
# 0
# 50971
# 79636
# 52610
# 0
# 50983
# 78029
# 52623
# 0
# 51006
# 74412
# 52647
# 0
# 52042
# 0
# 50821
# 65481

# %% [markdown]
# All covariates with multiple itemids have 100% of their observations in one itemid, no conversion or replacement needed, since there are no duplicates.

# %% [markdown]
# Creating time series data - time interval is hourly

# %%
# removing timestamp from intime
lab_data['intime'] = pd.to_datetime(lab_data['intime']).dt.tz_convert(None)

# %%
# Calculating time difference of each record of labevents from their admission
lab_data['timediff'] = (lab_data['charttime'] - lab_data['intime']).dt.total_seconds()/60/60

# %%
# Creating hour variable for time series
lab_data['hour'] = np.ceil(lab_data['timediff']).astype(int)

# %%
# I will call the label column as covariates 
lab_data['covariate'] = lab_data['label']

# %% [markdown]
# There are still records with valuenum == 0 and value has a 0 in its string...

# %%
lab_data[(lab_data['value'].isna())|(lab_data['valuenum']==0)]
# Out:
#          subject_id   hadm_id   stay_id              intime  itemid  \
# 261020     19390654  25268824  36561397 2111-04-24 20:03:45   51146
# 950518     14499007  24975279  32406577 2180-10-30 10:55:37   50912
# 1476306    10948115  28748915  32686693 2148-03-13 05:10:00   50970
# 1697504    14199761  29993089  30184363 2135-07-01 05:22:33   50885
# 1698192    11378149  29235017  31597960 2125-03-31 09:36:54   50885
# 1950045    17789287  25119406  38913968 2124-09-22 22:49:46   50885
# 2034326    11666315  23911356  34279325 2171-10-30 08:35:00   51146
# 2364266    14423216  25240724  35715575 2149-01-01 16:50:07   51301
# 2539777    16470848  27313327  39317251 2195-09-11 19:49:09   51146
# 2540766    11666315  23911356  34279325 2171-10-30 08:35:00   51200
# 2617516    15422389  21453368  34206149 2133-03-05 09:30:59   51301
# 2868839    18978412  29291201  36315545 2128-05-30 17:53:53   51301
# 2960774    14485790  27915057  32612531 2110-07-06 02:41:55   50885
# 3552027    19788705  23958189  36282338 2185-12-09 02:44:00   51146
# 3553118    12652268  23776614  35275563 2169-04-05 00:34:48   51146
# 3629981    16688268  25414679  33572547 2134-08-16 11:17:21   51301
# 3720751    13312439  26691985  38591822 2126-01-02 21:18:13   50885
# 3737929    17194724  23393833  31039970 2154-12-07 16:54:08   50912
# 3986778    10734735  28506107  30846763 2187-06-07 09:14:57   50912
# 4011558    17155997  26195056  34407047 2181-11-01 21:48:27   50912
# 4086695    10827578  20980039  34763877 2130-05-04 19:42:04   51146
# 4088546    14743163  26213518  30030100 2143-07-12 12:59:41   50885
# 4325167    14274191  21011573  38668223 2129-06-18 11:09:28   51244
# 4565079    12598727  28376297  34204437 2189-04-19 02:00:00   51146
# 4782791    19363370  24401955  32483247 2182-03-11 13:33:52   50893
# 5025140    16937967  25592861  39126421 2125-04-03 20:52:00   50912
# 5256568    17194724  23393833  31039970 2154-12-07 16:54:08   50912
# 6254809    16573207  21399919  34994922 2124-10-20 02:05:00   50885
#
#                      label           charttime value  valuenum valueuom  \
# 261020           Basophils 2111-04-25 04:05:00   0.0       0.0        %
# 950518          Creatinine 2180-10-27 15:15:00   0.0       0.0    mg/dL
# 1476306          Phosphate 2148-03-13 14:03:00   0.0       0.0    mg/dL
# 1697504   Bilirubin, Total 2135-07-01 14:02:00   0.0       0.0    mg/dL
# 1698192   Bilirubin, Total 2125-03-28 03:10:00   0.0       0.0    mg/dL
# 1950045   Bilirubin, Total 2124-09-23 04:46:00   0.0       0.0    mg/dL
# 2034326          Basophils 2171-10-31 02:50:00   0.0       0.0        %
# 2364266  White Blood Cells 2148-12-25 09:12:00    .0       0.0     K/uL
# 2539777          Basophils 2195-09-11 20:06:00   0.0       0.0        %
# 2540766        Eosinophils 2171-10-31 02:50:00   0.0       0.0        %
# 2617516  White Blood Cells 2133-03-04 00:55:00    .0       0.0     K/uL
# 2868839  White Blood Cells 2128-05-30 18:22:00    .0       0.0     K/uL
# 2960774   Bilirubin, Total 2110-06-18 09:27:00   0.0       0.0    mg/dL
# 3552027          Basophils 2185-12-08 20:20:00   0.0       0.0        %
# 3553118          Basophils 2169-03-14 00:00:00   0.0       0.0        %
# 3629981  White Blood Cells 2134-08-13 20:45:00    .0       0.0     K/uL
# 3720751   Bilirubin, Total 2125-12-31 05:02:00   0.0       0.0    mg/dL
# 3737929         Creatinine 2154-12-08 05:32:00   0.0       0.0    mg/dL
# 3986778         Creatinine 2187-06-06 06:20:00   0.0       0.0    mg/dL
# 4011558         Creatinine 2181-11-01 15:38:00   0.0       0.0    mg/dL
# 4086695          Basophils 2130-04-26 00:00:00   0.0       0.0        %
# 4088546   Bilirubin, Total 2143-07-13 06:00:00   0.0       0.0    mg/dL
# 4325167        Lymphocytes 2129-06-13 05:57:00   0.0       0.0        %
# 4565079          Basophils 2189-04-19 02:54:00   0.0       0.0        %
# 4782791     Calcium, Total 2182-03-11 14:48:00   0.0       0.0    mg/dL
# 5025140         Creatinine 2125-04-04 04:09:00   0.0       0.0    mg/dL
# 5256568         Creatinine 2154-12-07 22:22:00   0.0       0.0    mg/dL
# 6254809   Bilirubin, Total 2124-10-20 03:21:00   0.0       0.0    mg/dL
#
#            timediff  hour          covariate
# 261020     8.020833     9          Basophils
# 950518   -67.676944   -67         Creatinine
# 1476306    8.883333     9          Phosphate
# 1697504    8.657500     9   Bilirubin, Total
# 1698192  -78.448333   -78   Bilirubin, Total
# 1950045    5.937222     6   Bilirubin, Total
# 2034326   18.250000    19          Basophils
# 2364266 -175.635278  -175  White Blood Cells
# 2539777    0.280833     1          Basophils
# 2540766   18.250000    19        Eosinophils
# 2617516  -32.599722   -32  White Blood Cells
# 2868839    0.468611     1  White Blood Cells
# 2960774 -425.248611  -425   Bilirubin, Total
# 3552027   -6.400000    -6          Basophils
# 3553118 -528.580000  -528          Basophils
# 3629981  -62.539167   -62  White Blood Cells
# 3720751  -64.270278   -64   Bilirubin, Total
# 3737929   12.631111    13         Creatinine
# 3986778  -26.915833   -26         Creatinine
# 4011558   -6.174167    -6         Creatinine
# 4086695 -211.701111  -211          Basophils
# 4088546   17.005278    18   Bilirubin, Total
# 4325167 -125.207778  -125        Lymphocytes
# 4565079    0.900000     1          Basophils
# 4782791    1.235556     2     Calcium, Total
# 5025140    7.283333     8         Creatinine
# 5256568    5.464444     6         Creatinine
# 6254809    1.266667     2   Bilirubin, Total

# %% [markdown]
# Remove these and we should be OK to use valuenum only...

# %%
# Excluding these additional 0 values and keeping relevant columns
lab_data2=lab_data[(lab_data['value'].notna())&(lab_data['valuenum']!=0)][['subject_id', 'hadm_id', 'stay_id', 'hour', 'covariate', 'valuenum']]

# %%
display(lab_data2)
# Out:
#          subject_id   hadm_id   stay_id  hour         covariate  valuenum
# 5538       14353753  28959343  34466833   -41  Specific Gravity     1.023
# 5541       13210618  28886630  36754056   -26  Specific Gravity     1.009
# 5543       19585396  27682039  36167665   -43  Specific Gravity     1.015
# 5544       11374776  23440405  34927785     3  Specific Gravity     1.026
# 5552       12620262  20350913  33258240    14  Specific Gravity     1.026
# ...             ...       ...       ...   ...               ...       ...
# 6330374    18943220  27827180  36039755     1           Lactate     2.200
# 6330375    19654837  24963930  31165420   -96           Lactate     1.200
# 6330376    11917664  27344800  37501394    13           Lactate     7.700
# 6330379    10706411  22795641  31395458    16           Lactate     5.300
# 6330381    10244884  24320339  37378106    12           Lactate     6.500
#
# [2098462 rows x 6 columns]

# %% [markdown]
# Aggregating - I am not sure how each labevents variables need to be aggregated, it makes sense for me to average them.

# %%
lab_data3=lab_data2.groupby(['subject_id','hadm_id','stay_id','hour', 'covariate'], as_index=False).agg({'valuenum':[min,max]})

# %%
display(lab_data3)
# Out:
#         subject_id   hadm_id   stay_id hour             covariate valuenum  \
#                                                                        min
# 0         10000980  26913865  39765666   12                    PT    14.50
# 1         10000980  26913865  39765666   12                   PTT    69.60
# 2         10000980  26913865  39765666   22             Anion Gap    17.00
# 3         10000980  26913865  39765666   22           Bicarbonate    23.00
# 4         10000980  26913865  39765666   22        Calcium, Total     9.20
# ...            ...       ...       ...  ...                   ...      ...
# 2072410   19999987  23865745  36195440    7           Base Excess     1.00
# 2072411   19999987  23865745  36195440    7  Calculated Total CO2    28.00
# 2072412   19999987  23865745  36195440    7                  pCO2    44.00
# 2072413   19999987  23865745  36195440    7                    pH     7.39
# 2072414   19999987  23865745  36195440    7                   pO2   114.00
#
#
#             max
# 0         14.50
# 1         69.60
# 2         17.00
# 3         23.00
# 4          9.20
# ...         ...
# 2072410    1.00
# 2072411   28.00
# 2072412   44.00
# 2072413    7.39
# 2072414  114.00
#
# [2072415 rows x 7 columns]

# %%
lab_data3.columns = (lab_data3.columns.map('_'.join)
                  .str.replace('min','min')
                  .str.replace('max','max'))
display(lab_data3)
# Out:
#          subject_id_  hadm_id_  stay_id_  hour_            covariate_  \
# 0           10000980  26913865  39765666     12                    PT
# 1           10000980  26913865  39765666     12                   PTT
# 2           10000980  26913865  39765666     22             Anion Gap
# 3           10000980  26913865  39765666     22           Bicarbonate
# 4           10000980  26913865  39765666     22        Calcium, Total
# ...              ...       ...       ...    ...                   ...
# 2072410     19999987  23865745  36195440      7           Base Excess
# 2072411     19999987  23865745  36195440      7  Calculated Total CO2
# 2072412     19999987  23865745  36195440      7                  pCO2
# 2072413     19999987  23865745  36195440      7                    pH
# 2072414     19999987  23865745  36195440      7                   pO2
#
#          valuenum_min  valuenum_max
# 0               14.50         14.50
# 1               69.60         69.60
# 2               17.00         17.00
# 3               23.00         23.00
# 4                9.20          9.20
# ...               ...           ...
# 2072410          1.00          1.00
# 2072411         28.00         28.00
# 2072412         44.00         44.00
# 2072413          7.39          7.39
# 2072414        114.00        114.00
#
# [2072415 rows x 7 columns]

# %%
lab_data3.rename(columns = {'subject_id_':'subject_id', 'hadm_id_':'hadm_id', 'stay_id_':'stay_id', 'hour_':'hour', 'covariate_':'covariate'}, inplace = True)
display(lab_data3)
# Out:
#          subject_id   hadm_id   stay_id  hour             covariate  \
# 0          10000980  26913865  39765666    12                    PT
# 1          10000980  26913865  39765666    12                   PTT
# 2          10000980  26913865  39765666    22             Anion Gap
# 3          10000980  26913865  39765666    22           Bicarbonate
# 4          10000980  26913865  39765666    22        Calcium, Total
# ...             ...       ...       ...   ...                   ...
# 2072410    19999987  23865745  36195440     7           Base Excess
# 2072411    19999987  23865745  36195440     7  Calculated Total CO2
# 2072412    19999987  23865745  36195440     7                  pCO2
# 2072413    19999987  23865745  36195440     7                    pH
# 2072414    19999987  23865745  36195440     7                   pO2
#
#          valuenum_min  valuenum_max
# 0               14.50         14.50
# 1               69.60         69.60
# 2               17.00         17.00
# 3               23.00         23.00
# 4                9.20          9.20
# ...               ...           ...
# 2072410          1.00          1.00
# 2072411         28.00         28.00
# 2072412         44.00         44.00
# 2072413          7.39          7.39
# 2072414        114.00        114.00
#
# [2072415 rows x 7 columns]

# %%
pandas_gbq.to_gbq(lab_data3,'rnn_dataset.timeseries-lab-table', project_id=project_id, if_exists='replace')
# Out:
# 1it [00:41, 41.98s/it]

# %%
lab_data_final = run_query('''
SELECT *
FROM `genuine-box-350018.rnn_dataset.timeseries-lab-table`
''')
display(lab_data_final)
# Out:
#          subject_id   hadm_id   stay_id  hour             covariate  \
# 0          10000980  26913865  39765666    12                    PT
# 1          10000980  26913865  39765666    12                   PTT
# 2          10000980  26913865  39765666    22             Anion Gap
# 3          10000980  26913865  39765666    22           Bicarbonate
# 4          10000980  26913865  39765666    22        Calcium, Total
# ...             ...       ...       ...   ...                   ...
# 2072410    19999987  23865745  36195440     7           Base Excess
# 2072411    19999987  23865745  36195440     7  Calculated Total CO2
# 2072412    19999987  23865745  36195440     7                  pCO2
# 2072413    19999987  23865745  36195440     7                    pH
# 2072414    19999987  23865745  36195440     7                   pO2
#
#          valuenum_min  valuenum_max
# 0               14.50         14.50
# 1               69.60         69.60
# 2               17.00         17.00
# 3               23.00         23.00
# 4                9.20          9.20
# ...               ...           ...
# 2072410          1.00          1.00
# 2072411         28.00         28.00
# 2072412         44.00         44.00
# 2072413          7.39          7.39
# 2072414        114.00        114.00
#
# [2072415 rows x 7 columns]
